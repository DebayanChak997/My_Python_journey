# %%
print("hello World")
# Out:
# hello World

# %%
'''
Easy (1–10)

Print "Hello, World!"
Print your name and age in one line
Add two numbers and print the result
Print numbers from 1 to 5 using separate print statements
Print a square of * using print
Print the result of 10 / 3
Print the type of 5, 5.0, "5"
Print multiple values in one print statement
print a newline using escape characters
Print "Python" 5 times in one line
'''

# %%
print("Debayan","28")
# Out:
# Debayan 28

# %%
a=5;
b=6;
print(a+b)
# Out:
# 11

# %%
print(1)
# Out:
# 1

# %%
print(1)
print(2)
print(3)
print(4)
print(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print("****")
print("****")
print("****")
print("****")
# Out:
# ****
# ****
# ****
# ****

# %%
print(10/3)
# Out:
# 3.3333333333333335

# %%
type(5)
# Out:
# int

# %%
type(5)
type(5.0)
type("5")
# Out:
# str

# %%
type(5)
# Out:
# int

# %%
type(5.0)
# Out:
# float

# %%
type("5")
# Out:
# str

# %%
print(1,2,3,4,5)
# Out:
# 1 2 3 4 5

# %%
print(1,"\nhello")
# Out:
# 1
# hello

# %%
print("The number is:\n",1)
# Out:
# The number is:
#  1

# %%
print("python","python","python","python","python")
# Out:
# python python python python python

# %%
"""
Medium (11–20)
11. Read input and print it
12. Read two numbers and print their sum
13. Swap two numbers without using a third variable
14. Print the ASCII value of a character
15. Convert input string to integer and print double
16. Print last digit of a number
17. Print quotient and remainder
18. Print a formatted string using f-string
19. Print power of a number without using pow()
20. Print output of chained assignments
"""

# %%
a=input();
print(a);
# Out:
#  Hello is this working?
# Hello is this working?

# %%
a=int(input());
b=int(input());
print(a+b);
# Out:
#  25
#  40
# 65

# %%
a=int(input("a="));
b=int(input("b="));
b=a+b;
a=b-a
b=b-a
print("Ater swaping:a:",a,"b:",b)
# Out:
# a= 5
# b= 6
# Ater swaping:a: 6 b: 5

# %%
ascii(a)
# Out:
# '6'

# %%
ord('u')
# Out:
# 117

# %%
a=input()
int(a)
print(float(a))
# Out:
#  56
# 56.0

# %%
a=145
lastdigit=a%10
print(lastdigit)
# Out:
# 5

# %%
a=145
Remaider=a%10
Quiotent=a/10
print(Remaider)
print(Quiotent)
# Out:
# 5
# 14.5

# %%
a=28.5
print(f"My age is={a}")
# Out:
# My age is=28.5

# %%
a = 2
b = 3
result = a ** b
print(f"{a} raised to the power of {b} is: {result}")
# Out:
# 2 raised to the power of 3 is: 8

# %%
a,b=5,6
a, b = b, a
print(a,b)
# Out:
# 6 5

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a= int(input("Enter a number"))
b= int(input("Enter a number"))
c =a+b
print(c);
# Out:
# Enter a number 10
# Enter a number 20
# 30

# %%
salary = float(input("Enter your monthly salary:"))
yearly= salary *12
print("Your yearly salary is", yearly)
# Out:
# Enter your monthly salary: 18000
# Your yearly salary is 216000.0

# %%
age= int(input("Enter your age:"))
age = age+5

print("In 5 years, my age will be \033[4m" + str(age) + "\033[0m years")
# Out:
# Enter your age: 28
# In 5 years, my age will be 33 years
